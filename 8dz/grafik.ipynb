# %%
from matplotlib import pyplot as plt

# %%
file = open('dz8.txt')
f = file.readlines()
file.close()

# %%
va = []
vw = []
x = []
for i in range(0, len(f), 2):
    va.append(float(f[i]))
for j in range(1, len(f), 2):
    vw.append(float(f[j]))
for t in range(len(y)):
    x.append(int(t * 10))

# %%
plt.plot(x, va, label = 'Va') 
plt.plot(x, vw, label = 'Vw') 
plt.xlabel('Km')  
plt.ylabel('V')
plt.legend()
plt.show()
